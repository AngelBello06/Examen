# %%
# Problema 1
a = float(input(" Ingese el coeficiente del termino cuadrado: "))
b = float(input(" Ingese el coeficiente del termino que multiplica a la variable: "))
c = float(input(" Ingese el coeficiente de la constante: "))
di = (b**2-(4*a*c))
raiz = (di** .5)
x1 = ((-b-raiz)/(2*a))
x2 = ((-b+raiz)/(2*a))
while (di <= 0):
  print(" Error, el discriminante tiene que se positivo")
  a = float(input(" Ingese el coeficiente del termino cuadrado: "))
  b = float(input(" Ingese el coeficiente del termino que multiplica a la variable: "))
  c = float(input(" Ingese el coeficiente de la constante: "))
  di = (b**2-(4*a*c))
  raiz = (di** .5)
  x1 = ((-b+raiz)/(2*a))
  x2 = ((-b-raiz)/(2*a))
print(" Valor 1", x1)
print(" valor 2", x2)

# %%
# Problema 2
def exponencial(x):
  ex= (e**(-x))
  return ex
x = int(input("Ingrese un numero del -4 al 10 ")) 
e = 2.7182818284
x = exponencial(x)
print("El exponencial es: ",x)
contador = x-4
while contador <= 10:
  contador = contador + 1
  print(contador)
if contador < 0.0025:
  print(contador)
L=[0]
L.append(x-4)
L.append(x-3)
L.append(x-2)
L.append(x-1)
L.append(x+0)
L.append(x+1)
L.append(x+2)
L.append(x+3)
L.append(x+4)
L.append(x+5)
L.append(x+6)
L.append(x+7)
L.append(x+8)
L.append(x+9)
L.append(x+10)
print(L)
# Out:
# Ingrese un numero del -4 al 10 10
# El exponencial es:  4.539992977234643e-05
# -2.9999546000702275
# -1.9999546000702275
# -0.9999546000702275
# 4.539992977248275e-05
# 1.0000453999297725
# 2.0000453999297725
# 3.0000453999297725
# 4.000045399929773
# 5.000045399929773
# 6.000045399929773
# 7.000045399929773
# 8.000045399929773
# 9.000045399929773
# 10.000045399929773
# [0, -3.9999546000702275, -2.9999546000702275, -1.9999546000702277, -0.9999546000702276, 4.539992977234643e-05, 1.0000453999297723, 2.0000453999297725, 3.0000453999297725, 4.000045399929772, 5.000045399929772, 6.000045399929772, 7.000045399929772, 8.000045399929773, 9.000045399929773, 10.000045399929773]
